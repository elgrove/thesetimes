# %%
from bs4 import BeautifulSoup
import lxml
from datetime import datetime as dt
from core.utils.wsj import get_wsj_links

# %%
from core.utils.driver import driver_startup, driver_startup_headless

# %%
driver = driver_startup_headless()

# %%
headline_links = get_wsj_links(driver)

# %%
driver.get(headline_links[0])
page = driver.page_source.encode('utf-8')
soup = BeautifulSoup(page, 'lxml')

# %%
paras = [p.text for p in soup.find('article').find_all('p') if 'Copyright' not in p.text]

# %%
paras = [n.replace('\n', '').replace('    ', ' ') for n in paras if '@wsj.com' not in n]

# %%
bodysoup.find_all('p')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xf/g6sxxzt51ws1d5y2x5g_9qwm0000gn/T/ipykernel_69860/3144797262.py in <module>
# ----> 1 bodysoup.find_all('p')
#
# ~/dev/grovetimes/venv/lib/python3.9/site-packages/bs4/element.py in __getattr__(self, key)
#    2251     def __getattr__(self, key):
#    2252         """Raise a helpful exception to explain a common code fix."""
# -> 2253         raise AttributeError(
#    2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
dt.strptime(
        soup.find("meta", attrs={"name": "article.published"}).get("content"),
        "%Y-%m-%dT%H:%M:%S.%fZ",
    )
# Out:
# datetime.datetime(2021, 10, 25, 13, 14)

# %%
driver.quit()

# %%
ww = 'https://www.wsj.com/amp/articles/sudanese-prime-minister-detained-in-apparent-military-coup-11635150306?mod=hp_lead_pos10'

# %%
ww.replace('/amp/', '/')
# Out:
# 'https://www.wsj.com/articles/sudanese-prime-minister-detained-in-apparent-military-coup-11635150306?mod=hp_lead_pos10'
